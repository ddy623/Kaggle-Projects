# %%
import pandas as pd
df = pandas.read_csv('dogs_dataset.csv')
import matplotlib.pyplot as plt
import seaborn as sns
df
# Out:
#                      Breed  Age (Years)  Weight (kg)    Color  Gender
# 0         Airedale Terrier           13           35    White    Male
# 1     Jack Russell Terrier           10           43      Tan  Female
# 2           Dogo Argentino            2           16  Spotted  Female
# 3       Labrador Retriever            9           57  Bicolor    Male
# 4           French Bulldog           12           39  Spotted    Male
# ...                    ...          ...          ...      ...     ...
# 2995        Siberian Husky            5           25      Tan  Female
# 2996                Vizsla           11           34     Blue  Female
# 2997             Pekingese            4           49  Bicolor    Male
# 2998               Samoyed           13            7     Blue  Female
# 2999  Pembroke Welsh Corgi            7           19    White  Female
#
# [3000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Breed        3000 non-null   object
#  1   Age (Years)  3000 non-null   int64
#  2   Weight (kg)  3000 non-null   int64
#  3   Color        3000 non-null   object
#  4   Gender       3000 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 117.3+ KB

# %% [markdown]
# Analyzing Data

# %%
# Identify columns with numeric data you want to aggregate
numeric_columns = ['Age (Years)', 'Weight (kg)']

# %%
# Calculate mean for numeric columns only
df[numeric_columns].mean()
# Out:
# Age (Years)     7.499000
# Weight (kg)    32.059667
# dtype: float64

# %%
df['Breed'].value_counts()
# Out:
# Breed
# Rottweiler                       118
# French Bulldog                    70
# Pekingese                         68
# Pembroke Welsh Corgi              67
# Doberman Pinscher                 66
# Weimaraner                        66
# Pug                               65
# Bichon Frise                      64
# Vizsla                            64
# Cavalier King Charles Spaniel     64
# Chinese Shar-Pei                  64
# Poodle                            61
# Whippet                           60
# Dachshund                         59
# Cocker Spaniel                    59
# Bloodhound                        59
# Border Collie                     57
# Lhasa Apso                        56
# Samoyed                           56
# Bernese Mountain Dog              56
# Alaskan Malamute                  55
# Miniature Schnauzer               55
# Jack Russell Terrier              55
# Bulldog                           55
# Airedale Terrier                  55
# ...

# %%
df.groupby('Color').agg({'Age (Years)':['mean','max', 'count','sum'] })
# Out:
#                 Age (Years)
#                        mean max count   sum
# Color
# Bicolor            8.250000  14   200  1650
# Black              6.907609  14   184  1271
# Black and Tan      7.051813  14   193  1361
# Black and White    7.702439  14   205  1579
# Blue               7.178010  14   191  1371
# Brindle            7.640000  14   200  1528
# Brown              7.867725  14   189  1487
# Cream              7.969512  14   164  1307
# Gray               7.564246  14   179  1354
# Merle              6.979899  14   199  1389
# Red                7.281081  14   185  1347
# Sable              7.773869  14   199  1547
# Spotted            6.942408  14   191  1326
# Tan                7.433526  14   173  1286
# Tricolor           7.680723  14   166  1275
# White              7.796703  14   182  1419

# %%
df.groupby('Gender').agg({'Age (Years)':['mean','max', 'count','sum'] })
# Out:
#        Age (Years)
#               mean max count    sum
# Gender
# Female    7.510526  14  1520  11416
# Male      7.487162  14  1480  11081

# %%
df.groupby('Breed').agg({'Age (Years)':['mean','max', 'count','sum'] })
# Out:
#                               Age (Years)
#                                      mean max count  sum
# Breed
# Airedale Terrier                 8.218182  14    55  452
# Akita                            7.784314  14    51  397
# Alaskan Malamute                 6.981818  14    55  384
# Australian Shepherd              7.823529  14    51  399
# Basenji                          7.551020  14    49  370
# Beagle                           7.636364  14    55  420
# Belgian Malinois                 8.363636  14    44  368
# Bernese Mountain Dog             6.785714  14    56  380
# Bichon Frise                     6.500000  14    64  416
# Bloodhound                       7.237288  14    59  427
# Border Collie                    7.859649  14    57  448
# Boston Terrier                   7.735849  14    53  410
# Boxer                            8.557692  14    52  445
# Bull Terrier                     6.618182  14    55  364
# Bulldog                          7.290909  14    55  401
# ...

# %% [markdown]
# The data shows that there are more female than male dogs, as there was 1520 female and 1480 males. The average age of 7 to 8 years with the max age of 14 years old.  It also showed many breeds and many different colors.  The majority of the dogs in the sample were Rottweilers, as the sample had 118 in the sample.

# %% [markdown]
# Explore Data Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Create a countplot for categorical data
# Seaborn countplot
fig, ax = plt.subplots(figsize=(12, 6))
sns.countplot(data=df, x='Breed', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %%
#Create a countplot for categorical data
# Seaborn countplot
fig, ax = plt.subplots(figsize=(12, 6))
sns.countplot(data=df, x='Gender', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()
